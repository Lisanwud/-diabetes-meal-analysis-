# %% [markdown]
# # Prepare Food-101 Dataset
#
# This notebook processes the Food-101 dataset, organizing it into train, validation, and test directories for use in training the food recognition model.

# %%
import os
import shutil
import random
import json

# %% [markdown]
# ## Define Paths
#
# Set up paths for the raw dataset and output directories.

# %%
# Paths
raw_data_dir = '../data/food101/food-101/images'
output_dir = '../data/food101'
train_dir = os.path.join(output_dir, 'train')
valid_dir = os.path.join(output_dir, 'validation')
test_dir = os.path.join(output_dir, 'test')

# Create output directories
for dir_path in [train_dir, valid_dir, test_dir]:
    os.makedirs(dir_path, exist_ok=True)

# %% [markdown]
# ## Split Dataset
#
# Split the dataset into 70% train, 15% validation, and 15% test, maintaining class balance.

# %%
# Get list of food classes
food_classes = sorted(os.listdir(raw_data_dir))
random.seed(42)  # For reproducibility

for food_class in food_classes:
    class_path = os.path.join(raw_data_dir, food_class)
    if not os.path.isdir(class_path):
        continue
    
    # Get all images
    images = [f for f in os.listdir(class_path) if f.endswith('.jpg')]
    random.shuffle(images)
    
    # Calculate split sizes
    total = len(images)
    train_count = int(total * 0.70)
    valid_count = int(total * 0.15)
    test_count = total - train_count - valid_count
    
    # Assign images to splits
    train_images = images[:train_count]
    valid_images = images[train_count:train_count + valid_count]
    test_images = images[train_count + valid_count:]
    
    # Copy images to respective directories
    for split, split_images, split_dir in [
        ('train', train_images, train_dir),
        ('validation', valid_images, valid_dir),
        ('test', test_images, test_dir)
    ]:
        class_split_dir = os.path.join(split_dir, food_class)
        os.makedirs(class_split_dir, exist_ok=True)
        for img in split_images:
            src = os.path.join(class_path, img)
            dst = os.path.join(class_split_dir, img)
            shutil.copyfile(src, dst)
        print(f'Copied {len(split_images)} images to {split}/{food_class}')
# Out:
# Copied 700 images to train/apple_pie
# Copied 150 images to validation/apple_pie
# Copied 150 images to test/apple_pie
# Copied 700 images to train/baby_back_ribs
# Copied 150 images to validation/baby_back_ribs
# Copied 150 images to test/baby_back_ribs
# Copied 700 images to train/baklava
# Copied 150 images to validation/baklava
# Copied 150 images to test/baklava
# Copied 700 images to train/beef_carpaccio
# Copied 150 images to validation/beef_carpaccio
# Copied 150 images to test/beef_carpaccio
# Copied 700 images to train/beef_tartare
# Copied 150 images to validation/beef_tartare
# Copied 150 images to test/beef_tartare
# Copied 700 images to train/beet_salad
# Copied 150 images to validation/beet_salad
# Copied 150 images to test/beet_salad
# Copied 700 images to train/beignets
# Copied 150 images to validation/beignets
# Copied 150 images to test/beignets
# Copied 700 images to train/bibimbap
# Copied 150 images to validation/bibimbap
# Copied 150 images to test/bibimbap
# Copied 700 images to train/bread_pudding
# Copied 150 images to validation/bread_pudding
# Copied 150 images to test/bread_pudding
# Copied 700 images to train/breakfast_burrito
# Copied 150 images to validation/breakfast_burrito
# Copied 150 images to test/breakfast_burrito
# Copied 700 images to train/bruschetta
# Copied 150 images to validation/bruschetta
# Copied 150 images to test/bruschetta
# Copied 700 images to train/caesar_salad
# Copied 150 images to validation/caesar_salad
# Copied 150 images to test/caesar_salad
# Copied 700 images to train/cannoli
# Copied 150 images to validation/cannoli
# Copied 150 images to test/cannoli
# Copied 700 images to train/caprese_salad
# Copied 150 images to validation/caprese_salad
# Copied 150 images to test/caprese_salad
# Copied 700 images to train/carrot_cake
# Copied 150 images to validation/carrot_cake
# Copied 150 images to test/carrot_cake
# Copied 700 images to train/ceviche
# Copied 150 images to validation/ceviche
# Copied 150 images to test/ceviche
# Copied 700 images to train/cheese_plate
# Copied 150 images to validation/cheese_plate
# Copied 150 images to test/cheese_plate
# Copied 700 images to train/cheesecake
# Copied 150 images to validation/cheesecake
# Copied 150 images to test/cheesecake
# Copied 700 images to train/chicken_curry
# Copied 150 images to validation/chicken_curry
# Copied 150 images to test/chicken_curry
# Copied 700 images to train/chicken_quesadilla
# Copied 150 images to validation/chicken_quesadilla
# Copied 150 images to test/chicken_quesadilla
# Copied 700 images to train/chicken_wings
# Copied 150 images to validation/chicken_wings
# Copied 150 images to test/chicken_wings
# Copied 700 images to train/chocolate_cake
# Copied 150 images to validation/chocolate_cake
# Copied 150 images to test/chocolate_cake
# Copied 700 images to train/chocolate_mousse
# Copied 150 images to validation/chocolate_mousse
# Copied 150 images to test/chocolate_mousse
# Copied 700 images to train/churros
# Copied 150 images to validation/churros
# Copied 150 images to test/churros
# Copied 700 images to train/clam_chowder
# Copied 150 images to validation/clam_chowder
# Copied 150 images to test/clam_chowder
# Copied 700 images to train/club_sandwich
# Copied 150 images to validation/club_sandwich
# Copied 150 images to test/club_sandwich
# Copied 700 images to train/crab_cakes
# Copied 150 images to validation/crab_cakes
# Copied 150 images to test/crab_cakes
# Copied 700 images to train/creme_brulee
# Copied 150 images to validation/creme_brulee
# Copied 150 images to test/creme_brulee
# Copied 700 images to train/croque_madame
# Copied 150 images to validation/croque_madame
# Copied 150 images to test/croque_madame
# Copied 700 images to train/cup_cakes
# Copied 150 images to validation/cup_cakes
# Copied 150 images to test/cup_cakes
# Copied 700 images to train/deviled_eggs
# Copied 150 images to validation/deviled_eggs
# Copied 150 images to test/deviled_eggs
# Copied 700 images to train/donuts
# Copied 150 images to validation/donuts
# Copied 150 images to test/donuts
# Copied 700 images to train/dumplings
# Copied 150 images to validation/dumplings
# Copied 150 images to test/dumplings
# Copied 700 images to train/edamame
# Copied 150 images to validation/edamame
# Copied 150 images to test/edamame
# Copied 700 images to train/eggs_benedict
# Copied 150 images to validation/eggs_benedict
# Copied 150 images to test/eggs_benedict
# Copied 700 images to train/escargots
# Copied 150 images to validation/escargots
# Copied 150 images to test/escargots
# Copied 700 images to train/falafel
# Copied 150 images to validation/falafel
# Copied 150 images to test/falafel
# Copied 700 images to train/filet_mignon
# Copied 150 images to validation/filet_mignon
# Copied 150 images to test/filet_mignon
# Copied 700 images to train/fish_and_chips
# Copied 150 images to validation/fish_and_chips
# Copied 150 images to test/fish_and_chips
# Copied 700 images to train/foie_gras
# Copied 150 images to validation/foie_gras
# Copied 150 images to test/foie_gras
# Copied 700 images to train/french_fries
# Copied 150 images to validation/french_fries
# Copied 150 images to test/french_fries
# Copied 700 images to train/french_onion_soup
# Copied 150 images to validation/french_onion_soup
# Copied 150 images to test/french_onion_soup
# Copied 700 images to train/french_toast
# Copied 150 images to validation/french_toast
# Copied 150 images to test/french_toast
# Copied 700 images to train/fried_calamari
# Copied 150 images to validation/fried_calamari
# Copied 150 images to test/fried_calamari
# Copied 700 images to train/fried_rice
# Copied 150 images to validation/fried_rice
# Copied 150 images to test/fried_rice
# Copied 700 images to train/frozen_yogurt
# Copied 150 images to validation/frozen_yogurt
# Copied 150 images to test/frozen_yogurt
# Copied 700 images to train/garlic_bread
# Copied 150 images to validation/garlic_bread
# Copied 150 images to test/garlic_bread
# Copied 700 images to train/gnocchi
# Copied 150 images to validation/gnocchi
# Copied 150 images to test/gnocchi
# Copied 700 images to train/greek_salad
# Copied 150 images to validation/greek_salad
# Copied 150 images to test/greek_salad
# Copied 700 images to train/grilled_cheese_sandwich
# Copied 150 images to validation/grilled_cheese_sandwich
# Copied 150 images to test/grilled_cheese_sandwich
# Copied 700 images to train/grilled_salmon
# Copied 150 images to validation/grilled_salmon
# Copied 150 images to test/grilled_salmon
# Copied 700 images to train/guacamole
# Copied 150 images to validation/guacamole
# Copied 150 images to test/guacamole
# Copied 700 images to train/gyoza
# Copied 150 images to validation/gyoza
# Copied 150 images to test/gyoza
# Copied 700 images to train/hamburger
# Copied 150 images to validation/hamburger
# Copied 150 images to test/hamburger
# Copied 700 images to train/hot_and_sour_soup
# Copied 150 images to validation/hot_and_sour_soup
# Copied 150 images to test/hot_and_sour_soup
# Copied 700 images to train/hot_dog
# Copied 150 images to validation/hot_dog
# Copied 150 images to test/hot_dog
# Copied 700 images to train/huevos_rancheros
# Copied 150 images to validation/huevos_rancheros
# Copied 150 images to test/huevos_rancheros
# Copied 700 images to train/hummus
# Copied 150 images to validation/hummus
# Copied 150 images to test/hummus
# Copied 700 images to train/ice_cream
# Copied 150 images to validation/ice_cream
# Copied 150 images to test/ice_cream
# Copied 700 images to train/lasagna
# Copied 150 images to validation/lasagna
# Copied 150 images to test/lasagna
# Copied 700 images to train/lobster_bisque
# Copied 150 images to validation/lobster_bisque
# Copied 150 images to test/lobster_bisque
# Copied 700 images to train/lobster_roll_sandwich
# Copied 150 images to validation/lobster_roll_sandwich
# Copied 150 images to test/lobster_roll_sandwich
# Copied 700 images to train/macaroni_and_cheese
# Copied 150 images to validation/macaroni_and_cheese
# Copied 150 images to test/macaroni_and_cheese
# Copied 700 images to train/macarons
# Copied 150 images to validation/macarons
# Copied 150 images to test/macarons
# Copied 700 images to train/miso_soup
# Copied 150 images to validation/miso_soup
# Copied 150 images to test/miso_soup
# Copied 700 images to train/mussels
# Copied 150 images to validation/mussels
# Copied 150 images to test/mussels
# Copied 700 images to train/nachos
# Copied 150 images to validation/nachos
# Copied 150 images to test/nachos
# Copied 700 images to train/omelette
# Copied 150 images to validation/omelette
# Copied 150 images to test/omelette
# Copied 700 images to train/onion_rings
# Copied 150 images to validation/onion_rings
# Copied 150 images to test/onion_rings
# Copied 700 images to train/oysters
# Copied 150 images to validation/oysters
# Copied 150 images to test/oysters
# Copied 700 images to train/pad_thai
# Copied 150 images to validation/pad_thai
# Copied 150 images to test/pad_thai
# Copied 700 images to train/paella
# Copied 150 images to validation/paella
# Copied 150 images to test/paella
# Copied 700 images to train/pancakes
# Copied 150 images to validation/pancakes
# Copied 150 images to test/pancakes
# Copied 700 images to train/panna_cotta
# Copied 150 images to validation/panna_cotta
# Copied 150 images to test/panna_cotta
# Copied 700 images to train/peking_duck
# Copied 150 images to validation/peking_duck
# Copied 150 images to test/peking_duck
# Copied 700 images to train/pho
# Copied 150 images to validation/pho
# Copied 150 images to test/pho
# Copied 700 images to train/pizza
# Copied 150 images to validation/pizza
# Copied 150 images to test/pizza
# Copied 700 images to train/pork_chop
# Copied 150 images to validation/pork_chop
# Copied 150 images to test/pork_chop
# Copied 700 images to train/poutine
# Copied 150 images to validation/poutine
# Copied 150 images to test/poutine
# Copied 700 images to train/prime_rib
# Copied 150 images to validation/prime_rib
# Copied 150 images to test/prime_rib
# Copied 700 images to train/pulled_pork_sandwich
# Copied 150 images to validation/pulled_pork_sandwich
# Copied 150 images to test/pulled_pork_sandwich
# Copied 700 images to train/ramen
# Copied 150 images to validation/ramen
# Copied 150 images to test/ramen
# Copied 700 images to train/ravioli
# Copied 150 images to validation/ravioli
# Copied 150 images to test/ravioli
# Copied 700 images to train/red_velvet_cake
# Copied 150 images to validation/red_velvet_cake
# Copied 150 images to test/red_velvet_cake
# Copied 700 images to train/risotto
# Copied 150 images to validation/risotto
# Copied 150 images to test/risotto
# Copied 700 images to train/samosa
# Copied 150 images to validation/samosa
# Copied 150 images to test/samosa
# Copied 700 images to train/sashimi
# Copied 150 images to validation/sashimi
# Copied 150 images to test/sashimi
# Copied 700 images to train/scallops
# Copied 150 images to validation/scallops
# Copied 150 images to test/scallops
# Copied 700 images to train/seaweed_salad
# Copied 150 images to validation/seaweed_salad
# Copied 150 images to test/seaweed_salad
# Copied 700 images to train/shrimp_and_grits
# Copied 150 images to validation/shrimp_and_grits
# Copied 150 images to test/shrimp_and_grits
# Copied 700 images to train/spaghetti_bolognese
# Copied 150 images to validation/spaghetti_bolognese
# Copied 150 images to test/spaghetti_bolognese
# Copied 700 images to train/spaghetti_carbonara
# Copied 150 images to validation/spaghetti_carbonara
# Copied 150 images to test/spaghetti_carbonara
# Copied 700 images to train/spring_rolls
# Copied 150 images to validation/spring_rolls
# Copied 150 images to test/spring_rolls
# Copied 700 images to train/steak
# Copied 150 images to validation/steak
# Copied 150 images to test/steak
# Copied 700 images to train/strawberry_shortcake
# Copied 150 images to validation/strawberry_shortcake
# Copied 150 images to test/strawberry_shortcake
# Copied 700 images to train/sushi
# Copied 150 images to validation/sushi
# Copied 150 images to test/sushi
# Copied 700 images to train/tacos
# Copied 150 images to validation/tacos
# Copied 150 images to test/tacos
# Copied 700 images to train/takoyaki
# Copied 150 images to validation/takoyaki
# Copied 150 images to test/takoyaki
# Copied 700 images to train/tiramisu
# Copied 150 images to validation/tiramisu
# Copied 150 images to test/tiramisu
# Copied 700 images to train/tuna_tartare
# Copied 150 images to validation/tuna_tartare
# Copied 150 images to test/tuna_tartare
# Copied 700 images to train/waffles
# Copied 150 images to validation/waffles
# Copied 150 images to test/waffles

# %% [markdown]
# ## Save Class Labels
#
# Save the list of food classes to `food_classes.json` for use in model inference.

# %%
# Save class labels
with open('../models/food_classes.json', 'w') as f:
    json.dump(food_classes, f)
print('Saved food classes to models/food_classes.json')
# Out:
# Saved food classes to models/food_classes.json

# %% [markdown]
# ## Verify Splits
#
# Check the number of images in each split to ensure correctness.

# %%
def count_images(directory):
    total = 0
    for root, _, files in os.walk(directory):
        total += len([f for f in files if f.endswith('.jpg')])
    return total

print(f'Train images: {count_images(train_dir)}')
print(f'Validation images: {count_images(valid_dir)}')
print(f'Test images: {count_images(test_dir)}')
# Out:
# Train images: 70700
# Validation images: 15150
# Test images: 15150
